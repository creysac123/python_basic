# %% [markdown]
# ### 1. What does RGBA stand for?

# %% [markdown]
# RGBA stands for Red Green Blue Alpha. It is a color model that represents colors using combinations of red, green, and blue values, along with an additional alpha value that represents the transparency or opacity of the color.

# %% [markdown]
# ### 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import Image

image = Image.open('#The Batman 2021 Exclusive Wallpaper.jpg')

x = 100
y = 200
rgba = image.getpixel((x, y))

print(rgba)
# Out:
# (198, 92, 6)

# %%
from PIL import Image, ImageColor

im = ImageColor.getcolor("orange", "L")
print(im)

im1 = ImageColor.getcolor("red", "L")
print(im1)
# Out:
# 173
# 76

# %% [markdown]
# ### 3. What is a box tuple, and how does it work?

# %%
from PIL import Image

image = Image.open('#The Batman 2021 Exclusive Wallpaper.jpg')

box = (100, 100, 300, 300)

cropped_image = image.crop(box)

cropped_image.show()
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F1180F2FC40>

# %% [markdown]
# ### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
im=Image.open('#The Batman 2021 Exclusive Wallpaper.jpg')
width, height = im.size
print("width=", width)
print("height=", height)
# Out:
# width= 1080
# height= 605

# %% [markdown]
# ### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
from PIL import Image

image = Image.open('#The Batman 2021 Exclusive Wallpaper.jpg')

box = (0, 50, 50, 100)

cropped_image = image.crop(box)

cropped_image.show()
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7F1180F2D8D0>

# %% [markdown]
# ### 6. After making changes to an Image object, how could you save it as an image file?

# %%
from PIL import Image

image = Image.open('original_image.jpg')

image.save('modified_image.jpg')

# %% [markdown]
# ### 7. What module contains Pillow’s shape-drawing code?

# %%
from PIL import Image, ImageDraw

# %% [markdown]
# ### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
from PIL import Image, ImageDraw

image = Image.open('#The Batman 2021 Exclusive Wallpaper.jpg')

draw = ImageDraw.Draw(image)

image.save('modified_image.jpg')

# %%
image.show('modified_image.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x605 at 0x7F117007C640>
